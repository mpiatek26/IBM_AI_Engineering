# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# Load the dataset
data = pd.read_csv('https://cocl.us/concrete_data')

# Assuming the target column is named 'concrete_strength'. 
# Please replace it with the actual column name for concrete strength in your dataset
X_data = data.drop('Strength', axis=1)
Y_data = data['Strength']

mean_squared_errors = []

for i in range(50):
    # Splitting the data
    X_train, X_test, y_train, y_test = train_test_split(X_data, Y_data, test_size=0.3)

    # Defining the model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(1))

    # Compiling the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Training the model
    model.fit(X_train, y_train, epochs=50, verbose=0)

    # Predicting using the model
    y_pred = model.predict(X_test)

    # Computing the mean squared error
    mse = mean_squared_error(y_test, y_pred)

    # Appending to the list
    mean_squared_errors.append(mse)

# Converting list to numpy array
mean_squared_errors = np.array(mean_squared_errors)

# Reporting the mean and standard deviation of the mean squared errors
print("Mean of Mean Squared Errors: ", np.mean(mean_squared_errors))
print("Standard Deviation of Mean Squared Errors: ", np.std(mean_squared_errors))
# Out:
# 10/10 [==============================] - 0s 424us/step
# 10/10 [==============================] - 0s 319us/step
# 10/10 [==============================] - 0s 383us/step
# 10/10 [==============================] - 0s 340us/step
# 10/10 [==============================] - 0s 385us/step
# 10/10 [==============================] - 0s 359us/step
# 10/10 [==============================] - 0s 462us/step
# 10/10 [==============================] - 0s 389us/step
# 10/10 [==============================] - 0s 368us/step
# 10/10 [==============================] - 0s 370us/step
# 10/10 [==============================] - 0s 440us/step
# 10/10 [==============================] - 0s 354us/step
# 10/10 [==============================] - 0s 420us/step
# 10/10 [==============================] - 0s 369us/step
# 10/10 [==============================] - 0s 419us/step
# 10/10 [==============================] - 0s 380us/step
# 10/10 [==============================] - 0s 373us/step
# 10/10 [==============================] - 0s 367us/step
# 10/10 [==============================] - 0s 408us/step
# 10/10 [==============================] - 0s 359us/step
# 10/10 [==============================] - 0s 360us/step
# 10/10 [==============================] - 0s 358us/step
# 10/10 [==============================] - 0s 350us/step
# 10/10 [==============================] - 0s 347us/step
# 10/10 [==============================] - 0s 360us/step
# 10/10 [==============================] - 0s 339us/step
# 10/10 [==============================] - 0s 345us/step
# 10/10 [==============================] - 0s 416us/step
# 10/10 [==============================] - 0s 349us/step
# 10/10 [==============================] - 0s 501us/step
# 10/10 [==============================] - 0s 373us/step
# 10/10 [==============================] - 0s 399us/step
# 10/10 [==============================] - 0s 342us/step
# 10/10 [==============================] - 0s 366us/step
# 10/10 [==============================] - 0s 385us/step
# 10/10 [==============================] - 0s 371us/step
# 10/10 [==============================] - 0s 387us/step
# 10/10 [==============================] - 0s 341us/step
# 10/10 [==============================] - 0s 421us/step
# 10/10 [==============================] - 0s 399us/step
# 10/10 [==============================] - 0s 374us/step
# 10/10 [==============================] - 0s 415us/step
# 10/10 [==============================] - 0s 425us/step
# 10/10 [==============================] - 0s 384us/step
# 10/10 [==============================] - 0s 332us/step
# 10/10 [==============================] - 0s 414us/step
# 10/10 [==============================] - 0s 416us/step
# 10/10 [==============================] - 0s 453us/step
# 10/10 [==============================] - 0s 386us/step
# 10/10 [==============================] - 0s 343us/step
# Mean of Mean Squared Errors:  269.27836943436466
# Standard Deviation of Mean Squared Errors:  258.0893613191939
